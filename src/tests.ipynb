# %% [markdown]
# # First things first, import data analysis tools

# %%
import numpy as np
import pandas as pd

# for standardization
from sklearn.preprocessing import StandardScaler

# For PCA, SVD, and NMF
from sklearn.decomposition import PCA, TruncatedSVD, NMF

# %% [markdown]
# # Testing that everything works locally

# %%
# Visualization
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create plot
plt.plot(x, y)

# Labels and title
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Simple Line Plot")

# Show it
plt.show()

# %%
import seaborn as sns

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

sns.lineplot(x=x, y=y)

plt.title("Simple Seaborn Line Plot")
plt.show()

# %%
import folium

# Create a map centered somewhere
m = folium.Map(location=[39.9242, -83.8088], zoom_start=12)  # Springfield, OH

# Save to HTML
m.save("../tests/map.html")

# %%
import plotly.express as px
import plotly.io as pio
# this bypasses an issue on my end regarding VSCode integrated rendering
pio.renderers.default = "browser"


df = px.data.iris()

fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show(renderer="browser")
